# %% [markdown]
# <a href="https://colab.research.google.com/github/warriorwizard/calculating_chi_square_of_ILPD_dataset/blob/main/calculating_chi_square_of_ILPD_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as numpy
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/ILPD.csv')

# %%
df.head()
# Out:
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB    AG  SELECTOR
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90         1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74         1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89         1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00         1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40         1

# %%
label_encoder = LabelEncoder()
df['Gender'] = label_encoder.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB    AG  SELECTOR
# 0   65       0   0.7  0.1      187    16    18  6.8  3.3  0.90         1
# 1   62       1  10.9  5.5      699    64   100  7.5  3.2  0.74         1
# 2   62       1   7.3  4.1      490    60    68  7.0  3.3  0.89         1
# 3   58       1   1.0  0.4      182    14    20  6.8  3.4  1.00         1
# 4   72       1   3.9  2.0      195    27    59  7.3  2.4  0.40         1

# %%
df.describe()
# Out:
#               Age      Gender          TB          DB      ALKPHOS  \
# count  583.000000  583.000000  583.000000  583.000000   583.000000
# mean    44.746141    0.756432    3.298799    1.486106   290.576329
# std     16.189833    0.429603    6.209522    2.808498   242.937989
# min      4.000000    0.000000    0.400000    0.100000    63.000000
# 25%     33.000000    1.000000    0.800000    0.200000   175.500000
# 50%     45.000000    1.000000    1.000000    0.300000   208.000000
# 75%     58.000000    1.000000    2.600000    1.300000   298.000000
# max     90.000000    1.000000   75.000000   19.700000  2110.000000
#
#               SGPT         SGOT          TP         ALB          AG  \
# count   583.000000   583.000000  583.000000  583.000000  583.000000
# mean     80.713551   109.910806    6.483190    3.141852    0.947770
# std     182.620356   288.918529    1.085451    0.795519    0.319333
# min      10.000000    10.000000    2.700000    0.900000    0.300000
# ...

# %%
from sklearn.feature_selection import chi2

# %%
X = df.drop('SELECTOR',axis=1)
y = df['SELECTOR']

# %%
X.head()
# Out:
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB    AG
# 0   65       0   0.7  0.1      187    16    18  6.8  3.3  0.90
# 1   62       1  10.9  5.5      699    64   100  7.5  3.2  0.74
# 2   62       1   7.3  4.1      490    60    68  7.0  3.3  0.89
# 3   58       1   1.0  0.4      182    14    20  6.8  3.4  1.00
# 4   72       1   3.9  2.0      195    27    59  7.3  2.4  0.40

# %% [markdown]
# ## here first array represents chi square values and second array represnts p-values

# %%
chi_scores = chi2(X,y)
chi_scores
# Out:
# (array([6.43151737e+01, 9.64518373e-01, 3.29873827e+02, 1.87005784e+02,
#         4.03985570e+03, 6.42191995e+03, 1.02033290e+04, 1.29627007e-01,
#         3.05337122e+00, 1.78598678e+00]),
#  array([1.06026038e-15, 3.26051096e-01, 1.02392469e-73, 1.43195838e-42,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.18819085e-01,
#         8.05697402e-02, 1.81415900e-01]))
